# %%
#import nltk; nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Seema\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# True

# %%
import pandas as pd
import numpy as np
import re
from pprint import pprint
import pickle

# Gensim
import gensim
import gensim.corpora as corpora
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel
from gensim.parsing.preprocessing import STOPWORDS as SW
from gensim.models import LdaMulticore
from wordcloud import STOPWORDS
stopwords = set(STOPWORDS)
from nltk.corpus import stopwords as nltk_SW

# spacy for lemmatization
import spacy
from spacy.tokenizer import Tokenizer

# Plotting tools
import pyLDAvis
import pyLDAvis.gensim 
import matplotlib.pyplot as plt
# %matplotlib inline

# Enable logging for gensim
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.ERROR)

import warnings
warnings.filterwarnings("ignore",category=DeprecationWarning)

# %%
% run config.ipynb

# %%
% run data_preprocessing.ipynb

# %%
% run nlp_preprocessing.ipynb

# %%
% run topic_model.ipynb

# %%
# Load processed .pkl file
df = load_processed_data()
# Out:
# After removing outliers
# Total Rows: 295390 , Total Columns: 6 , Total Memory Usage (Bytes): 16541840

# %%
df.head()
# Out:
#                business_id               review_id  stars       date  \
# 4   PfOCPjBrlQAnz__NXj9h_w  sa6lbcuzaMkjVegOT21t8Q      5 2017-05-29
# 10  PfOCPjBrlQAnz__NXj9h_w  BRHnn4cqgGfMfZXOpcqZHQ      5 2016-01-13
# 11  PfOCPjBrlQAnz__NXj9h_w  QyForzRygHhPsHY2b174mg      5 2016-02-24
# 14  PfOCPjBrlQAnz__NXj9h_w  fQR2uXHOOs-hPvdRvwJ-OA      4 2017-08-05
# 18  PfOCPjBrlQAnz__NXj9h_w  Nb-hzSY3AbSvHVhEHP58Qw      3 2016-11-06
#
#                                                  text  text_len
# 4   Been going here for years and it's still my fa...       132
# 10  everyone was so friendly and the drinks were g...       157
# 11  Good beer and even better food. Staff is atten...       180
# 14  Never been in the area and decided to stop wit...       177
# 18  Good service, nice atmosphere, the filet is ho...       149

# %% [markdown]
# ## NLP Processing

# %%
# Load pre trained model

#spacy.cli.download("en_core_web_lg")
# Out:
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_lg')

# %%
nlp = spacy.load('en_core_web_sm', disable=['parser', 'ner'])

# %%
# Clean Text
df['clean_text'] = df['text'].apply(clean_text)

# %%
data_lemmatized = generate_lemma_text(df['clean_text'])

# %%
df['data_lemmatized'] = data_lemmatized

# Save lemma output
save_preprocessed_data(df, file_name_lemmatized)

# %% [markdown]
# ## Checkpoint  for clean lemma tokens

# %%
df = load_pkl_file(file_name_lemmatized)

# %%
df.head()
# Out:
#                business_id               review_id  stars       date  \
# 4   PfOCPjBrlQAnz__NXj9h_w  sa6lbcuzaMkjVegOT21t8Q      5 2017-05-29
# 10  PfOCPjBrlQAnz__NXj9h_w  BRHnn4cqgGfMfZXOpcqZHQ      5 2016-01-13
# 11  PfOCPjBrlQAnz__NXj9h_w  QyForzRygHhPsHY2b174mg      5 2016-02-24
# 14  PfOCPjBrlQAnz__NXj9h_w  fQR2uXHOOs-hPvdRvwJ-OA      4 2017-08-05
# 18  PfOCPjBrlQAnz__NXj9h_w  Nb-hzSY3AbSvHVhEHP58Qw      3 2016-11-06
#
#                                                  text  text_len  \
# 4   Been going here for years and it's still my fa...       132
# 10  everyone was so friendly and the drinks were g...       157
# 11  Good beer and even better food. Staff is atten...       180
# 14  Never been in the area and decided to stop wit...       177
# 18  Good service, nice atmosphere, the filet is ho...       149
#
#                                            clean_text  \
# 4   been going here for years and it's still my fa...
# 10  everyone was so friendly and the drinks were g...
# 11  good beer and even better food staff is attent...
# 14  never been in the area and decided to stop wit...
# 18  good service nice atmosphere the filet is horr...
#
#                                       data_lemmatized
# 4   [go, year, still, favorite, server, friendly, ...
# 10  [friendly, drink, good, food, amazing, comfy, ...
# 11  [good, beer, even, well, food, staff, attentiv...
# 14  [never, area, decide, stop, friend, cool, atmo...
# 18  [good, service, nice, atmosphere, horrendous, ...

# %% [markdown]
# ## Vectorization

# %%
df = df[df['date']>='2017-07-01']
print(df.shape)

id2word, corpus = vectorization(data_lemmatized)
# Out:
# (73232, 8)

# %% [markdown]
# ## LDA Model

# %%
lda_model, perplexity_lda, coherence_lda = generate_topic_model_lda(id2word, corpus, data_lemmatized)
# Out:
# [(0,
#   '0.076*"love" + 0.051*"sushi" + 0.038*"favorite" + 0.034*"new" + '
#   '0.033*"good" + 0.031*"roll" + 0.026*"spot" + 0.025*"work" + 0.014*"people" '
#   '+ 0.013*"fresh"'),
#  (1,
#   '0.140*"always" + 0.051*"food" + 0.049*"great" + 0.045*"visit" + '
#   '0.043*"time" + 0.040*"love" + 0.034*"service" + 0.028*"good" + 0.026*"eat" '
#   '+ 0.020*"year"'),
#  (2,
#   '0.143*"time" + 0.059*"wait" + 0.052*"first" + 0.047*"back" + 0.042*"food" + '
#   '0.037*"long" + 0.024*"service" + 0.021*"come" + 0.019*"good" + 0.017*"go"'),
#  (3,
#   '0.050*"never" + 0.036*"disappoint" + 0.028*"soup" + 0.022*"food" + '
#   '0.021*"bad" + 0.021*"review" + 0.020*"delivery" + 0.020*"chinese" + '
#   '0.020*"good" + 0.016*"order"'),
#  (4,
#   '0.191*"pizza" + 0.046*"close" + 0.041*"open" + 0.020*"twice" + 0.019*"good" '
#   '+ 0.018*"late" + 0.016*"call" + 0.015*"pm" + 0.014*"say" + 0.014*"crust"'),
#  (5,
#   '0.089*"good" + 0.060*"food" + 0.048*"beer" + 0.045*"great" + '
#   '0.039*"selection" + 0.034*"nice" + 0.026*"price" + 0.024*"service" + '
#   '0.019*"bar" + 0.019*"pretty"'),
#  (6,
#   '0.056*"good" + 0.052*"chicken" + 0.027*"sauce" + 0.023*"little" + '
#   '0.022*"side" + 0.020*"bit" + 0.019*"spicy" + 0.019*"love" + 0.016*"rice" + '
#   '0.016*"really"'),
#  (7,
#   '0.079*"take" + 0.027*"food" + 0.019*"care" + 0.016*"location" + '
#   '0.016*"business" + 0.016*"good" + 0.016*"dining" + 0.014*"tell" + '
#   '0.013*"shop" + 0.013*"manager"'),
#  (8,
#   '0.076*"great" + 0.056*"good" + 0.054*"food" + 0.051*"service" + '
#   '0.035*"thank" + 0.026*"awesome" + 0.021*"make" + 0.019*"local" + '
#   '0.018*"guy" + 0.015*"nice"'),
#  (9,
#   '0.073*"service" + 0.068*"food" + 0.028*"slow" + 0.026*"good" + 0.024*"give" '
#   '+ 0.021*"bad" + 0.019*"star" + 0.017*"terrible" + 0.017*"wrong" + '
#   '0.017*"rude"'),
#  (10,
#   '0.087*"recommend" + 0.060*"food" + 0.058*"great" + 0.046*"highly" + '
#   '0.041*"price" + 0.040*"service" + 0.034*"good" + 0.033*"portion" + '
#   '0.032*"quick" + 0.023*"fresh"'),
#  (11,
#   '0.035*"bad" + 0.034*"food" + 0.025*"good" + 0.023*"ever" + 0.022*"wait" + '
#   '0.020*"worth" + 0.018*"service" + 0.018*"minute" + 0.017*"money" + '
#   '0.016*"even"'),
#  (12,
#   '0.047*"cook" + 0.038*"shrimp" + 0.027*"beef" + 0.025*"fresh" + 0.024*"fish" '
#   '+ 0.024*"good" + 0.022*"pho" + 0.016*"perfectly" + 0.014*"food" + '
#   '0.014*"warm"'),
#  (13,
#   '0.083*"breakfast" + 0.056*"good" + 0.054*"coffee" + 0.027*"great" + '
#   '0.027*"sweet" + 0.021*"brunch" + 0.018*"friendly" + 0.018*"egg" + '
#   '0.018*"service" + 0.018*"pancake"'),
#  (14,
#   '0.110*"great" + 0.101*"food" + 0.085*"service" + 0.055*"excellent" + '
#   '0.034*"amazing" + 0.031*"good" + 0.023*"love" + 0.022*"authentic" + '
#   '0.021*"back" + 0.018*"definitely"'),
#  (15,
#   '0.073*"burger" + 0.062*"good" + 0.062*"taco" + 0.054*"fry" + 0.037*"wing" + '
#   '0.027*"great" + 0.022*"fish" + 0.021*"chip" + 0.021*"steak" + '
#   '0.020*"option"'),
#  (16,
#   '0.080*"salad" + 0.071*"good" + 0.065*"sandwich" + 0.027*"chicken" + '
#   '0.025*"cheese" + 0.018*"bread" + 0.017*"pasta" + 0.016*"get" + '
#   '0.016*"grill" + 0.015*"stuff"'),
#  (17,
#   '0.049*"quality" + 0.049*"well" + 0.045*"food" + 0.039*"good" + '
#   '0.028*"place" + 0.027*"price" + 0.021*"expensive" + 0.020*"much" + '
#   '0.018*"die" + 0.015*"eat"'),
#  (18,
#   '0.082*"friendly" + 0.074*"staff" + 0.070*"definitely" + 0.061*"back" + '
#   '0.053*"food" + 0.046*"super" + 0.036*"good" + 0.034*"great" + 0.029*"nice" '
#   '+ 0.029*"really"'),
#  (19,
#   '0.096*"great" + 0.052*"food" + 0.042*"atmosphere" + 0.037*"happy" + '
#   '0.029*"drink" + 0.027*"hour" + 0.025*"service" + 0.025*"fun" + 0.023*"love" '
#   '+ 0.022*"good"')]
#
# Perplexity:  -8.204115101920616
#
# Coherence Score:  0.3503785046294006
# Average topic coherence: -3.4847.
# [([(0.08230077, 'friendly'),
#    (0.07424273, 'staff'),
#    (0.07021273, 'definitely'),
#    (0.06061146, 'back'),
#    (0.053248502, 'food'),
#    (0.046320613, 'super'),
#    (0.03559913, 'good'),
#    (0.03376555, 'great'),
#    (0.029410116, 'nice'),
#    (0.028779246, 'really'),
#    (0.02355481, 'amazing'),
#    (0.021460675, 'service'),
#    (0.020823603, 'come'),
#    (0.014513132, 'clean'),
#    (0.014320432, 'helpful'),
#    (0.013501565, 'delicious'),
#    (0.012937497, 'fast'),
#    (0.012015421, 'attentive'),
#    (0.009227056, 'awesome'),
#    (0.009097596, 'worth')],
#   -2.7071513728469005),
#  ([(0.09641189, 'great'),
#    (0.0517414, 'food'),
#    (0.042307924, 'atmosphere'),
#    (0.036801852, 'happy'),
#    (0.029410996, 'drink'),
#    (0.027391624, 'hour'),
#    (0.025254969, 'service'),
#    (0.024895111, 'fun'),
#    (0.02279008, 'love'),
#    (0.022052072, 'good'),
#    (0.017071377, 'bar'),
#    (0.017032348, 'nice'),
#    (0.01667176, 'music'),
#    (0.016573636, 'staff'),
#    (0.015558327, 'awesome'),
#    (0.014595508, 'server'),
#    (0.014278754, 'friendly'),
#    (0.012496891, 'cool'),
#    (0.011653968, 'night'),
#    (0.011433445, 'vibe')],
#   -2.949904664772814),
#  ([(0.08694184, 'recommend'),
#    (0.060399063, 'food'),
#    (0.05791866, 'great'),
#    (0.04621982, 'highly'),
#    (0.041366484, 'price'),
#    (0.03981018, 'service'),
#    (0.03429942, 'good'),
#    (0.03257013, 'portion'),
#    (0.032110695, 'quick'),
#    (0.022803385, 'fresh'),
#    (0.020398797, 'lunch'),
#    (0.018219182, 'friendly'),
#    (0.017370025, 'delicious'),
#    (0.017235383, 'reasonable'),
#    (0.016385056, 'large'),
#    (0.0141354, 'tasty'),
#    (0.01244819, 'healthy'),
#    (0.011875369, 'huge'),
#    (0.011407151, 'fast'),
#    (0.011164718, 'amazing')],
#   -3.0219474316798567),
#  ([(0.08948513, 'good'),
#    (0.059994485, 'food'),
#    (0.047932006, 'beer'),
#    (0.04465285, 'great'),
#    (0.038729165, 'selection'),
#    (0.03436301, 'nice'),
#    (0.026218796, 'price'),
#    (0.024122788, 'service'),
#    (0.01949488, 'bar'),
#    (0.0191393, 'pretty'),
#    (0.016349407, 'decent'),
#    (0.015780235, 'wine'),
#    (0.012536109, 'really'),
#    (0.011722726, 'lot'),
#    (0.011404514, 'menu'),
#    (0.010201184, 'high'),
#    (0.009904902, 'little'),
#    (0.009402363, 'atmosphere'),
#    (0.008758337, 'area'),
#    (0.007927357, 'staff')],
#   -3.0394346443302824),
#  ([(0.109833434, 'great'),
#    (0.10081432, 'food'),
#    (0.084628865, 'service'),
#    (0.05523161, 'excellent'),
#    (0.03369389, 'amazing'),
#    (0.030674325, 'good'),
#    (0.022862138, 'love'),
#    (0.02152333, 'authentic'),
#    (0.020735348, 'back'),
#    (0.017527094, 'definitely'),
#    (0.01543891, 'atmosphere'),
#    (0.014769093, 'mexican'),
#    (0.0118029155, 'delicious'),
#    (0.011520326, 'fantastic'),
#    (0.0105015375, 'awesome'),
#    (0.009921213, 'dinner'),
#    (0.009030754, 'family'),
#    (0.008959602, 'price'),
#    (0.008758624, 'absolutely'),
#    (0.008722697, 'customer')],
#   -3.0472473438037686),
#  ([(0.14045884, 'always'),
#    (0.05085671, 'food'),
#    (0.049216386, 'great'),
#    (0.0445323, 'visit'),
#    (0.04297125, 'time'),
#    (0.03961873, 'love'),
#    (0.034445502, 'service'),
#    (0.027982848, 'good'),
#    (0.025512094, 'eat'),
#    (0.02043676, 'year'),
#    (0.01877554, 'week'),
#    (0.018330565, 'last'),
#    (0.016979452, 'favorite'),
#    (0.010787953, 'fresh'),
#    (0.01057785, 'amazing'),
#    (0.009935437, 'couple'),
#    (0.00945685, 'least'),
#    (0.0093757035, 'delicious'),
#    (0.008613556, 'friendly'),
#    (0.008538912, 'town')],
#   -3.1114419018820545),
#  ([(0.056382477, 'good'),
#    (0.05176229, 'chicken'),
#    (0.026896853, 'sauce'),
#    (0.022924475, 'little'),
#    (0.022467429, 'side'),
#    (0.019875696, 'bit'),
#    (0.019401943, 'spicy'),
#    (0.01904784, 'love'),
#    (0.015635097, 'rice'),
#    (0.015579105, 'really'),
#    (0.014369838, 'great'),
#    (0.014181104, 'meat'),
#    (0.013171523, 'portion'),
#    (0.013123168, 'food'),
#    (0.012494533, 'small'),
#    (0.011278698, 'fry'),
#    (0.011246132, 'pricey'),
#    (0.010773229, 'green'),
#    (0.010720274, 'bowl'),
#    (0.010654571, 'delicious')],
#   -3.1772961551172982),
#  ([(0.14340368, 'time'),
#    (0.059190508, 'wait'),
#    (0.051875442, 'first'),
#    (0.047173224, 'back'),
#    (0.04194469, 'food'),
#    (0.036672764, 'long'),
#    (0.02399356, 'service'),
#    (0.021498246, 'come'),
#    (0.0191176, 'good'),
#    (0.017474694, 'go'),
#    (0.017346846, 'next'),
#    (0.016943412, 'great'),
#    (0.015575534, 'line'),
#    (0.012768538, 'definitely'),
#    (0.012539767, 'soon'),
#    (0.012478494, 'worth'),
#    (0.010709595, 'amazing'),
#    (0.009848491, 'chef'),
#    (0.009370211, 'take'),
#    (0.008609225, 'second')],
#   -3.1948422455955816),
#  ([(0.082718626, 'breakfast'),
#    (0.056243356, 'good'),
#    (0.053852845, 'coffee'),
#    (0.027065044, 'great'),
#    (0.026940722, 'sweet'),
#    (0.02132666, 'brunch'),
#    (0.018267184, 'friendly'),
#    (0.018041017, 'egg'),
#    (0.017734658, 'service'),
#    (0.017595895, 'pancake'),
#    (0.016321274, 'cute'),
#    (0.01599215, 'love'),
#    (0.015835658, 'waffle'),
#    (0.015253421, 'staff'),
#    (0.015197081, 'potato'),
#    (0.013487534, 'bacon'),
#    (0.011931744, 'delicious'),
#    (0.01184021, 'nice'),
#    (0.011099507, 'spot'),
#    (0.010477103, 'crepe')],
#   -3.331287549992651),
#  ([(0.07296183, 'burger'),
#    (0.062391926, 'good'),
#    (0.062219135, 'taco'),
#    (0.053815346, 'fry'),
#    (0.037330274, 'wing'),
#    (0.027430244, 'great'),
#    (0.021922838, 'fish'),
#    (0.021070313, 'chip'),
#    (0.020689044, 'steak'),
#    (0.019504827, 'option'),
#    (0.018567072, 'item'),
#    (0.016604796, 'well'),
#    (0.014539684, 'menu'),
#    (0.014443533, 'salsa'),
#    (0.014291982, 'love'),
#    (0.012349266, 'also'),
#    (0.012069611, 'chicken'),
#    (0.010969122, 'amazing'),
#    (0.010563074, 'meat'),
#    (0.010152126, 'vegetarian')],
#   -3.3918728898011063),
#  ([(0.047004055, 'cook'),
#    (0.037535615, 'shrimp'),
#    (0.027048763, 'beef'),
#    (0.025036143, 'fresh'),
#    (0.024174102, 'fish'),
#    (0.02380025, 'good'),
#    (0.021847527, 'pho'),
#    (0.0156171555, 'perfectly'),
#    (0.014463362, 'food'),
#    (0.014456239, 'warm'),
#    (0.014056126, 'fry'),
#    (0.013501524, 'chicken'),
#    (0.01230356, 'taste'),
#    (0.012252951, 'roll'),
#    (0.0106545575, 'order'),
#    (0.010385642, 'season'),
#    (0.009995787, 'back'),
#    (0.009904565, 'great'),
#    (0.009823613, 'vegetable'),
#    (0.009769837, 'perfection')],
#   -3.5302936248758012),
#  ([(0.07864517, 'take'),
#    (0.027080022, 'food'),
#    (0.019089963, 'care'),
#    (0.01628855, 'location'),
#    (0.015933052, 'business'),
#    (0.015926402, 'good'),
#    (0.015590889, 'dining'),
#    (0.013625054, 'tell'),
#    (0.013318276, 'shop'),
#    (0.012768553, 'manager'),
#    (0.01144802, 'experience'),
#    (0.011126143, 'get'),
#    (0.011047574, 'service'),
#    (0.010906698, 'help'),
#    (0.010615009, 'go'),
#    (0.009954416, 'seem'),
#    (0.009528728, 'room'),
#    (0.009456079, 'staff'),
#    (0.009331125, 'even'),
#    (0.009023267, 'need')],
#   -3.6157404661798807),
#  ([(0.035056546, 'bad'),
#    (0.033880882, 'food'),
#    (0.02476829, 'good'),
#    (0.022767374, 'ever'),
#    (0.022361262, 'wait'),
#    (0.019984923, 'worth'),
#    (0.018355617, 'service'),
#    (0.018312005, 'minute'),
#    (0.016812183, 'money'),
#    (0.015706541, 'even'),
#    (0.014363008, 'drive'),
#    (0.014112041, 'taste'),
#    (0.013808121, 'dog'),
#    (0.013778767, 'pay'),
#    (0.01321535, 'get'),
#    (0.0119713815, 'bland'),
#    (0.011473446, 'well'),
#    (0.011078392, 'water'),
#    (0.010965917, 'half'),
#    (0.010621171, 'eat')],
#   -3.686428733167001),
#  ([(0.0762286, 'great'),
#    (0.05637924, 'good'),
#    (0.053634018, 'food'),
#    (0.051209845, 'service'),
#    (0.034507595, 'thank'),
#    (0.02576453, 'awesome'),
#    (0.021405317, 'make'),
#    (0.018563014, 'local'),
#    (0.017667826, 'guy'),
#    (0.015237779, 'nice'),
#    (0.014211997, 'customer'),
#    (0.012893716, 'bartender'),
#    (0.012269835, 'experience'),
#    (0.011672979, 'keep'),
#    (0.011671559, 'vegan'),
#    (0.011302948, 'owner'),
#    (0.010758954, 'well'),
#    (0.010757314, 'feel'),
#    (0.010250861, 'job'),
#    (0.00948925, 'work')],
#   -3.700239789593051),
#  ([(0.049537174, 'never'),
#    (0.03632175, 'disappoint'),
#    (0.02840041, 'soup'),
#    (0.022352105, 'food'),
#    (0.021381255, 'bad'),
#    (0.021125624, 'review'),
#    (0.020469576, 'delivery'),
#    (0.020332912, 'chinese'),
#    (0.02025561, 'good'),
#    (0.016452122, 'order'),
#    (0.015349988, 'noodle'),
#    (0.015055134, 'star'),
#    (0.013925539, 'yelp'),
#    (0.012763916, 'say'),
#    (0.012019174, 'get'),
#    (0.011430434, 'taste'),
#    (0.011307021, 'hot'),
#    (0.011186261, 'dirty'),
#    (0.010851581, 'eat'),
#    (0.010675295, 'charge')],
#   -3.72842499176234),
#  ([(0.073426366, 'service'),
#    (0.06802504, 'food'),
#    (0.028061002, 'slow'),
#    (0.025978593, 'good'),
#    (0.02426625, 'give'),
#    (0.020506307, 'bad'),
#    (0.018572615, 'star'),
#    (0.0172223, 'terrible'),
#    (0.017047921, 'wrong'),
#    (0.016557008, 'rude'),
#    (0.016080957, 'customer'),
#    (0.012455587, 'back'),
#    (0.012407663, 'go'),
#    (0.011075853, 'never'),
#    (0.010626698, 'well'),
#    (0.0099947695, 'cold'),
#    (0.009840275, 'mediocre'),
#    (0.009517862, 'horrible'),
#    (0.009136098, 'reasonably_price'),
#    (0.008625909, 'ok')],
#   -3.73385834998095),
#  ([(0.048999406, 'quality'),
#    (0.048742864, 'well'),
#    (0.045496784, 'food'),
#    (0.03934739, 'good'),
#    (0.027936744, 'place'),
#    (0.026555808, 'price'),
#    (0.020618575, 'expensive'),
#    (0.020022212, 'much'),
#    (0.017609458, 'die'),
#    (0.015393065, 'eat'),
#    (0.014974622, 'fan'),
#    (0.014933426, 'restaurant'),
#    (0.013759658, 'buffet'),
#    (0.013444443, 'ingredient'),
#    (0.012461789, 'taste'),
#    (0.011460774, 'put'),
#    (0.010411706, 'way'),
#    (0.010089592, 'amazing'),
#    (0.010089196, 'big'),
#    (0.0097227525, 'high')],
#   -3.8467637154742014),
#  ([(0.076292105, 'love'),
#    (0.05065022, 'sushi'),
#    (0.037804924, 'favorite'),
#    (0.03394296, 'new'),
#    (0.032843415, 'good'),
#    (0.031264335, 'roll'),
#    (0.025532793, 'spot'),
#    (0.024776224, 'work'),
#    (0.013974089, 'people'),
#    (0.013414182, 'fresh'),
#    (0.011377019, 'amazing'),
#    (0.010535329, 'donut'),
#    (0.010066191, 'great'),
#    (0.01002067, 'whole'),
#    (0.009960652, 'location'),
#    (0.009705134, 'family'),
#    (0.00956944, 'cake'),
#    (0.009354837, 'girl'),
#    (0.009177836, 'town'),
#    (0.009171748, 'reservation')],
#   -4.030451561134371),
#  ([(0.080371976, 'salad'),
#    (0.07118169, 'good'),
#    (0.06521479, 'sandwich'),
#    (0.027033962, 'chicken'),
#    (0.024513528, 'cheese'),
#    (0.018234057, 'bread'),
#    (0.016579079, 'pasta'),
#    (0.016427739, 'get'),
#    (0.015713546, 'grill'),
#    (0.01521721, 'stuff'),
#    (0.013260727, 'also'),
#    (0.012422954, 'several'),
#    (0.011991888, 'order'),
#    (0.010791346, 'steak'),
#    (0.010509298, 'gyro'),
#    (0.010404217, 'ever'),
#    (0.009830066, 'amount'),
#    (0.009320795, 'lunch'),
#    (0.008802271, 'sausage'),
#    (0.008387697, 'appetizer')],
#   -4.1826797314060995),
#  ([(0.19083172, 'pizza'),
#    (0.046005517, 'close'),
#    (0.040895566, 'open'),
#    (0.019738743, 'twice'),
#    (0.019370714, 'good'),
#    (0.01838384, 'late'),
#    (0.016360004, 'call'),
#    (0.014808369, 'pm'),
#    (0.013845749, 'say'),
#    (0.013583643, 'crust'),
#    (0.013041115, 'topping'),
#    (0.0126429275, 'night'),
#    (0.01198095, 'brisket'),
#    (0.011613972, 'away'),
#    (0.01028258, 'get'),
#    (0.00952792, 'style'),
#    (0.009340887, 'early'),
#    (0.009333797, 'mushroom'),
#    (0.009018163, 'dine'),
#    (0.008918521, 'hour')],
#   -4.66643888464776)]

# %%
model_name = 'lda_model_baseline.pkl'
with open(file_path + model_name, 'wb') as f:
        pickle.dump(lda_model, f)

# %%
# %%time
# Visualize the topics
pyLDAvis.enable_notebook()
vis = pyLDAvis.gensim.prepare(lda_model, corpus, id2word)
vis
# Out:
# Wall time: 7min 55s

# %%
# Can take a long time to run.
model_list, coherence_values = compute_coherence_values(dictionary=id2word, corpus=corpus, texts=data_lemmatized, start=2, limit=30, step=6)
# Show graph

# %%
plot_coherence_values(coherence_values)

# %%
# Print the coherence scores
for m, cv in zip(x, coherence_values):
    print("Num Topics =", m, " has Coherence Value of", round(cv, 4))

# %%
# Select the model and print the topics
optimal_model = lda_model # model_list[3]
model_topics = optimal_model.show_topics(formatted=False)
pprint(optimal_model.print_topics(num_words=10))
# Out:
# [(0,
#   '0.076*"love" + 0.051*"sushi" + 0.038*"favorite" + 0.034*"new" + '
#   '0.033*"good" + 0.031*"roll" + 0.026*"spot" + 0.025*"work" + 0.014*"people" '
#   '+ 0.013*"fresh"'),
#  (1,
#   '0.140*"always" + 0.051*"food" + 0.049*"great" + 0.045*"visit" + '
#   '0.043*"time" + 0.040*"love" + 0.034*"service" + 0.028*"good" + 0.026*"eat" '
#   '+ 0.020*"year"'),
#  (2,
#   '0.143*"time" + 0.059*"wait" + 0.052*"first" + 0.047*"back" + 0.042*"food" + '
#   '0.037*"long" + 0.024*"service" + 0.021*"come" + 0.019*"good" + 0.017*"go"'),
#  (3,
#   '0.050*"never" + 0.036*"disappoint" + 0.028*"soup" + 0.022*"food" + '
#   '0.021*"bad" + 0.021*"review" + 0.020*"delivery" + 0.020*"chinese" + '
#   '0.020*"good" + 0.016*"order"'),
#  (4,
#   '0.191*"pizza" + 0.046*"close" + 0.041*"open" + 0.020*"twice" + 0.019*"good" '
#   '+ 0.018*"late" + 0.016*"call" + 0.015*"pm" + 0.014*"say" + 0.014*"crust"'),
#  (5,
#   '0.089*"good" + 0.060*"food" + 0.048*"beer" + 0.045*"great" + '
#   '0.039*"selection" + 0.034*"nice" + 0.026*"price" + 0.024*"service" + '
#   '0.019*"bar" + 0.019*"pretty"'),
#  (6,
#   '0.056*"good" + 0.052*"chicken" + 0.027*"sauce" + 0.023*"little" + '
#   '0.022*"side" + 0.020*"bit" + 0.019*"spicy" + 0.019*"love" + 0.016*"rice" + '
#   '0.016*"really"'),
#  (7,
#   '0.079*"take" + 0.027*"food" + 0.019*"care" + 0.016*"location" + '
#   '0.016*"business" + 0.016*"good" + 0.016*"dining" + 0.014*"tell" + '
#   '0.013*"shop" + 0.013*"manager"'),
#  (8,
#   '0.076*"great" + 0.056*"good" + 0.054*"food" + 0.051*"service" + '
#   '0.035*"thank" + 0.026*"awesome" + 0.021*"make" + 0.019*"local" + '
#   '0.018*"guy" + 0.015*"nice"'),
#  (9,
#   '0.073*"service" + 0.068*"food" + 0.028*"slow" + 0.026*"good" + 0.024*"give" '
#   '+ 0.021*"bad" + 0.019*"star" + 0.017*"terrible" + 0.017*"wrong" + '
#   '0.017*"rude"'),
#  (10,
#   '0.087*"recommend" + 0.060*"food" + 0.058*"great" + 0.046*"highly" + '
#   '0.041*"price" + 0.040*"service" + 0.034*"good" + 0.033*"portion" + '
#   '0.032*"quick" + 0.023*"fresh"'),
#  (11,
#   '0.035*"bad" + 0.034*"food" + 0.025*"good" + 0.023*"ever" + 0.022*"wait" + '
#   '0.020*"worth" + 0.018*"service" + 0.018*"minute" + 0.017*"money" + '
#   '0.016*"even"'),
#  (12,
#   '0.047*"cook" + 0.038*"shrimp" + 0.027*"beef" + 0.025*"fresh" + 0.024*"fish" '
#   '+ 0.024*"good" + 0.022*"pho" + 0.016*"perfectly" + 0.014*"food" + '
#   '0.014*"warm"'),
#  (13,
#   '0.083*"breakfast" + 0.056*"good" + 0.054*"coffee" + 0.027*"great" + '
#   '0.027*"sweet" + 0.021*"brunch" + 0.018*"friendly" + 0.018*"egg" + '
#   '0.018*"service" + 0.018*"pancake"'),
#  (14,
#   '0.110*"great" + 0.101*"food" + 0.085*"service" + 0.055*"excellent" + '
#   '0.034*"amazing" + 0.031*"good" + 0.023*"love" + 0.022*"authentic" + '
#   '0.021*"back" + 0.018*"definitely"'),
#  (15,
#   '0.073*"burger" + 0.062*"good" + 0.062*"taco" + 0.054*"fry" + 0.037*"wing" + '
#   '0.027*"great" + 0.022*"fish" + 0.021*"chip" + 0.021*"steak" + '
#   '0.020*"option"'),
#  (16,
#   '0.080*"salad" + 0.071*"good" + 0.065*"sandwich" + 0.027*"chicken" + '
#   '0.025*"cheese" + 0.018*"bread" + 0.017*"pasta" + 0.016*"get" + '
#   '0.016*"grill" + 0.015*"stuff"'),
#  (17,
#   '0.049*"quality" + 0.049*"well" + 0.045*"food" + 0.039*"good" + '
#   '0.028*"place" + 0.027*"price" + 0.021*"expensive" + 0.020*"much" + '
#   '0.018*"die" + 0.015*"eat"'),
#  (18,
#   '0.082*"friendly" + 0.074*"staff" + 0.070*"definitely" + 0.061*"back" + '
#   '0.053*"food" + 0.046*"super" + 0.036*"good" + 0.034*"great" + 0.029*"nice" '
#   '+ 0.029*"really"'),
#  (19,
#   '0.096*"great" + 0.052*"food" + 0.042*"atmosphere" + 0.037*"happy" + '
#   '0.029*"drink" + 0.027*"hour" + 0.025*"service" + 0.025*"fun" + 0.023*"love" '
#   '+ 0.022*"good"')]
